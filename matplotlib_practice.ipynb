# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis,y_axis, label = 'Boston', marker = "*", color="blue", linewidth = 2) # have to use legend to show label
plt.xlabel('Month')
plt.ylabel('Fares')
plt.title('PyBer Fare by Month')
plt.ylim(0,45)
plt.xlim(0,5)
plt.legend()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots() # returns a tuple - figure and axes objexts. THey are assigned to two variables
ax.plot(x_axis,y_axis, label = 'Boston')

# %%
#alternatively we can assign variable individually
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis,y_axis,color="green", marker="D",linewidth = 2,label="Boston")
ax.legend()
ax.set_title("Title")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_ylim(0,45)
ax.grid()
plt.show()
fig.savefig("fig.pdf")

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis,y_axis,color = "green", label = 'Boston')
plt.legend()
plt.xlabel("Date")
plt.ylabel("Fare")
plt.title("Bar Chart")
plt.show()
plt.barh(x_axis,y_axis,color = "magenta", label = 'Boston')
plt.gca().invert_yaxis() # get current axis
plt.legend()
plt.title("Title")
plt.xlabel("Date")
plt.ylabel("Fare")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## Bar chart with OO method# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
fig, ax = plt.subplots()
ax.bar(x_axis,y_axis, color = "k", label = "New York")
ax.legend()

# %%
fig, ax = plt.subplots()
ax.barh(x_axis,y_axis, color = "cyan", label = "Chicago")
ax.set_title("Title")
ax.set_xlabel("Fares")
ax.set_ylabel("Date")
ax.invert_yaxis() # no need for gca in OO method
#ax.gca().
ax.legend()

# %%
# Scatter Plots
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis,y_axis,'o') # add 'o' for scatter plot

# %%
plt.scatter(y_axis,x_axis, color = "Red", label = 'Chicago')
plt.legend()
plt.title("T")
plt.xlabel("x")
plt.ylabel("y")
plt.gca().invert_yaxis()
plt.xlim(15,40)
plt.show()

# %%
# Bubble
larger = []
for data in y_axis:
    larger+=([data*3])
    #print(larger)
plt.scatter(x_axis, y_axis, s=larger) # if is optional. this is called list comprehension

# %%
plt.scatter(x_axis, y_axis, s=[i*3 for i in y_axis if i > 0]) # if is optional. this is called list comprehension

# %%
# scatter with OO Interface
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# bubble with OO Interface
fig, ax = plt.subplots()
ax.scatter(y_axis,x_axis, s=[i*5 for i in y_axis], color="skyblue", alpha = .2, label = "legend")
ax.set_title("Title")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.invert_yaxis() # no need for gca in OO method
ax.set_xlim(0,50)
#ax.gca().
ax.legend()

# %%
# pie chart
plt.pie(y_axis, labels=x_axis, autopct = "%1.1f%%")
plt.show()

# %%
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
plt.subplots(figsize= (8,8)) # this is before plt.pie
explode = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, 
        labels=x_axis, 
        autopct = "%.1f%%",
        explode=explode,
       colors=colors)
plt.show()

# %%
# pie chart using OO interface
#fig, ax = plt.subplots()
#ax.pie(     y_axis,labels=x_axis,
 #           autopct = "%.1f%%"       
  #    )

# %%
# error bars
# %matplotlib inline
# Import dependencies.
import matplotlib.pyplot as plt
import statistics

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis,y_axis,yerr=stdev,capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.bar(x_axis,y_axis,yerr=stdev,capsize=3)
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
# major ticks
import numpy as np
plt.barh(x_axis,y_axis)
plt.xticks(np.arange(0,51, step=5.0))
plt.gca().invert_yaxis()

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))
plt.show()

# %%
# minor ticks
from matplotlib.ticker import MultipleLocator
# Increase the size of the plot figure.
fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))
# Create minor ticks at an increment of 1.
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()
